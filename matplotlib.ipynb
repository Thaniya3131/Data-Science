# %% [markdown]
# import matplotlib.pyplot as plt
# import numpy as np

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=[1,2,3,4]
y=[10,20,30,40]
plt.plot(x,y)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
students=['A','B','C']
marks=[10,20,30]
plt.bar(students,marks)
plt.show()

# %%
plt.barh(students,marks)
plt.show()

# %%
data=[1,1,2,2,3,3,3,4]
plt.hist(data)
plt.show()

# %%
data=[40,30,20,10]
labels=['A','B','C','D']
plt.pie(data,labels=labels)
plt.show()

# %%
data=[1,2,3,4,5]
plt.boxplot(data)
plt.show()

# %%
x=[1,2,3,4]
y=[2,4,6,8]
plt.fill_between(x,y)
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot([1,2,3],[4,5,6])

plt.subplot(1,2,2)
plt.plot([1,2,3],[6,5,4])
plt.show()

# %%
plt.title("Sales chart")
# Out:
# Text(0.5, 1.0, 'Sales chart')

# %%
plt.xlabel("X label")
# Out:
# Text(0.5, 0, 'X label')

# %%
plt.ylabel("Y label")
# Out:
# Text(0, 0.5, 'Y label')

# %%
plt.plot(x,y,label="Data")
plt.legend()
plt.show()

# %%
plt.grid(True)

# %%
x=[1,2,3]
y1=[2,4,6]
y2=[1,3,5]
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10,20,15,25]

plt.plot(x, y, color='blue', marker='o')

plt.title("Line Chart")
plt.xlabel("X Values")
plt.ylabel("Y Values")

plt.grid(True)

plt.show()

# %%
import numpy as np 

x=np.random.randint(1,10,size=6)
y=np.random.randint(2,7,size=6)
print(x,y)
# Out:
# [4 5 7 3 8 5] [6 4 6 2 6 2]

# %%
import matplotlib.pyplot as plt
plt.plot(x,y,color='green')

# %%
x=[1,2,3,4,5,6,7,8,9]
y=[10,20,30,40,50,60,70,80,90]
plt.plot(x,y)
plt.show()

# %%
import pandas as pd
df=pd.read_csv(r'D:\thaniya ds/student_dataset_10000_rows.csv')

# %%
df
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...

# %%
df.head(10)
# Out:
#    study_hours  attendance  sleep_hours  internet_usage  \
# 0            7          56            8               7
# 1            4          69            5               3
# 2           11          60            7               6
# 3            8          99            9               8
# 4            5          52            8               6
# 5            7          40            9              10
# 6           10          40            4              11
# 7            3          86            7               3
# 8            7          72            8               5
# 9           11          77            4               9
#
#    assignments_completed  previous_score  exam_score placement_status
# 0                     10              62      100.00           Placed
# 1                      8              56      100.00           Placed
# 2                     10              45      100.00           Placed
# ...

# %%
df.tail()
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 9995                      8              88       69.31       Not Placed
# 9996                      4              87      100.00           Placed
# 9997                     10              37       95.94           Placed
# 9998                      8              52       88.61           Placed
# 9999                     16              52       78.96           Placed

# %%
df.columns
# Out:
# Index(['study_hours', 'attendance', 'sleep_hours', 'internet_usage',
#        'assignments_completed', 'previous_score', 'exam_score',
#        'placement_status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   study_hours            10000 non-null  int64
#  1   attendance             10000 non-null  int64
#  2   sleep_hours            10000 non-null  int64
#  3   internet_usage         10000 non-null  int64
#  4   assignments_completed  10000 non-null  int64
#  5   previous_score         10000 non-null  int64
#  6   exam_score             10000 non-null  float64
#  7   placement_status       10000 non-null  object
# dtypes: float64(1), int64(6), object(1)
# memory usage: 625.1+ KB

# %%
df.describe()
# Out:
#         study_hours   attendance   sleep_hours  internet_usage  \
# count  10000.000000  10000.00000  10000.000000    10000.000000
# mean       5.989600     69.88460      6.498500        6.062600
# std        3.163589     17.61653      1.709354        3.138163
# min        1.000000     40.00000      4.000000        1.000000
# 25%        3.000000     55.00000      5.000000        3.000000
# 50%        6.000000     70.00000      6.500000        6.000000
# 75%        9.000000     85.00000      8.000000        9.000000
# max       11.000000    100.00000      9.000000       11.000000
#
#        assignments_completed  previous_score    exam_score
# count           10000.000000     10000.00000  10000.000000
# mean                9.988400        64.91100     86.704207
# std                 6.034145        17.50302     15.058383
# min                 0.000000        35.00000     26.670000
# 25%                 5.000000        50.00000     76.727500
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12,6))
plt.bar(df['study_hours'], df['exam_score'])
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(df['study_hours'],df['exam_score'])

plt.subplot(1,2,2)
plt.plot(df['attendance'],df['previous_score'],color='purple')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.bar(df['study_hours'], df['sleep_hours'])
plt.title("student performance prediction")
plt.xlabel("study_hours")
plt.ylabel("sleep_hours")
plt.show()

# %%
import matplotlib.pyplot as plt


plt.hist(df['exam_score'])

plt.title("Student Performance Prediction")
plt.xlabel("marks")
plt.ylabel("Students")

plt.show()

# %%
import matplotlib.pyplot as plt



plt.scatter(df['attendance'],df['assignments_completed'])

plt.title("Scatter Plot")
plt.xlabel("attendance")
plt.ylabel("assignments_completed")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(df['internet_usage'],df['exam_score'])

plt.title("Student Performance prediction")
plt.ylabel("exam score")
plt.xlabel("internet usage")

plt.show()

# %%
import matplotlib.pyplot as plt


plt.boxplot(df['internet_usage'])

plt.title("Student Performance Prediction")

plt.show()
