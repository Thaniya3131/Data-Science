# %%
x=5
y="john"
print(x)
print(y)
# Out:
# 5
# john

# %%
x=4
x="sally"
x=8
print(x)
# Out:
# 8

# %%
x=str(3)
y=int(3)
z=float(3)
print(x)
print(y)
print(z)
# Out:
# 3
# 3
# 3.0

# %%
x=5
y="john"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a = 4
A="Sally"
print(a)
print(A)
# Out:
# 4
# Sally

# %%
x,y,z="orange","banana","apple"
print(x)
print(y)
print(z)
# Out:
# orange
# banana
# apple

# %%
x=y=z="orange"
print(x)
print(y)
print(z)
# Out:
# orange
# orange
# orange

# %%
fruits=["apple","banana","cherry"]
x=y=z=fruits
print(x)
print(y)
print(z)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry']

# %%
x="python"
y="is"
z="awesome"
print(x,y,z)
# Out:
# python is awesome

# %%
x=5
print(type(x))
print(x)
# Out:
# <class 'int'>
# 5

# %%
x=1
y=2.8
z=1j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
x=1
y=37486497057467632
z=465987327
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x=1.10
y=1.0
z=-35.69
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x=3+5j
y=5j
z=-5j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
x=1
y=2.8
z=1j
a=float(x)
b=int(y)
c=complex(x)
print(a)
print(b)
print(c)
# Out:
# 1.0
# 2
# (1+0j)

# %%
x=int(1)
y=int(2.8)
z=int("3")
print(x)
print(y)
print(z)
# Out:
# 1
# 2
# 3

# %%
x=float(1)
y=float(2.8)
z=float("3")
w=float("4.2")
print(x)
print(y)
print(z)
print(w)
# Out:
# 1.0
# 2.8
# 3.0
# 4.2

# %%
x=str("s1")
y=str(2)
z=str(3.0)
print(x)
print(y)
print(z)
# Out:
# s1
# 2
# 3.0

# %%
a="Hello"
print(a)
# Out:
# Hello

# %%
a="""Lorem ipsum dolor sit amet,consectetur adipiscing elit,sed do eiusmod tempor incididunt ut labore et dolore magna aliqua."""
print(a)
# Out:
# Lorem ipsum dolor sit amet,consectetur adipiscing elit,sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.

# %%
a="Hello , world!"
print(a[1])
# Out:
# e

# %%
for x in "banana":
    print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
a="Hello,world!"
print(len(a))
# Out:
# 12

# %%
txt="The best things in life are free!"
print("free" in txt)
# Out:
# True

# %%
txt="The best things in life are free!"
if"free"in txt:
    print("Yes,'free'is present")
# Out:
# Yes,'free'is present

# %%
txt="The best things in life are free!"
print("expensive" not in txt)
# Out:
# True

# %%
b="Hello,world!"
print(b[2:5])
# Out:
# llo

# %%
a=b="Hello,world!"
print(b[:5])
print(b[2:])
print(b[-5:-2])
print(a.upper())
print(a.lower())
# Out:
# Hello
# llo,world!
# orl
# HELLO,WORLD!
# hello,world!

# %%
a=" Hello, World!"
print(len(a))
print(a.strip())
print(a.replace("H","J"))
print(a.split(","))
# Out:
# 14
# Hello, World!
#  Jello, World!
# [' Hello', ' World!']

# %%
a="Hello"
b="World"
c=a + b
print(c)
# Out:
# HelloWorld

# %%
print(10>9)
print(10==9)
print(10<9)
# Out:
# True
# False
# False

# %%
a=200
b=33
if b>a:
  print("b is greater than a")
else:
  print("b is not greater than a")
# Out:
# b is not greater than a

# %%
print(bool("Hello"))
print(bool(15))
# Out:
# True
# True

# %%
mylist=["apple","banana","cherry"]
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist=["apple","banana","cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist=["apple","banana","cherry","apple","cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'cherry']

# %%
thislist=["apple","banana","cherry"]
print(len(thislist))
# Out:
# 3

# %%
list1=["apple","banana","cherry"]
list2=[1,5,7,9,3]
list3=[True,False,False]
print(list1)
print(list2)
print(list3)
# Out:
# ['apple', 'banana', 'cherry']
# [1, 5, 7, 9, 3]
# [True, False, False]

# %%
list1=["abc",34,True,40,"male"]
print(list1)
# Out:
# ['abc', 34, True, 40, 'male']

# %%
mylist=["apple","banana","cherry"]
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist=list(("apple","banana","cherry","orange","kiwi","melon","mango"))
print(thislist[1])
print(thislist[-1])
print(thislist[2:5])
print(thislist[:4])
print(thislist[-4:-1])
# Out:
# banana
# mango
# ['cherry', 'orange', 'kiwi']
# ['apple', 'banana', 'cherry', 'orange']
# ['orange', 'kiwi', 'melon']

# %%
thislist=["apple","banana","cherry"]
thislist.append("orange")
print(thislist)
thislist.insert(1,"orange")
print(thislist)
thislist.remove("banana")
print(thislist)
for x in thislist:
  print(x)
  for i in range(len(thislist)):
    print(thislist[i])
# Out:
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'orange', 'banana', 'cherry', 'orange']
# ['apple', 'orange', 'cherry', 'orange']
# apple
# apple
# orange
# cherry
# orange
# orange
# apple
# orange
# cherry
# orange
# cherry
# apple
# orange
# cherry
# orange
# orange
# apple
# orange
# cherry
# orange

# %%
mytuple=("apple","banana","cherry")
thistuple=("apple","banana","cherry")
print(thistuple)
print(thistuple[-1])
print(thistuple[1])
# Out:
# ('apple', 'banana', 'cherry')
# cherry
# banana

# %%
thistuple=("apple","banana","cherry","orange","kiwi","melon","mango")
print(thistuple[:4])
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
myset={"apple","banana","cherry"}
thisset={"apple","banana","cherry"}
print(thisset)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
signal=input("enter the traffic signals:")
if signal=="Red" :
    print("STOP")
elif signal=="Yellow" :
    print("READY")
elif signal=="Green" :
    print("GO")
else:
    print("Invalid Input")

# %%
charge=int(input("Enter your battery level:"))
if charge>=90 :
    print("Your battery is full")
elif charge>=50 :
    print("Battery is okay")
else:
    print("Battery low")
# Out:
# Enter your battery level: 56
# Battery is okay

# %%
rows = 5

# %%
myset={"apple","banana","cherry"}
thisset={"apple","banana","cherry"}
print(thisset)
# Out:
# {'apple', 'banana', 'cherry'}

# %%
set1={"apple","banana","cherry"}
set2={1,5,7,9,3}
set3={True,False,False}
print(set1)
print(set2)
print(set3)
# Out:
# {'apple', 'banana', 'cherry'}
# {1, 3, 5, 7, 9}
# {False, True}

# %%
thisset={"apple","banana","cherry"}
for x in thisset:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
thisset={"apple","banana","cherry"}
for x in thisset:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
set1={"a","b","c"}
set2={1,2,3}
set3=set1.union(set2)
print(set3)
# Out:
# {'b', 'c', 1, 2, 3, 'a'}

# %%
set1={"a","b","c"}
set2={1,2,3}
set3=set1|set2
print(set3)
# Out:
# {'b', 'c', 1, 2, 3, 'a'}

# %%
num=int(input("Enter the numbers or sentence:"))
count=int(input("Enter the count:"))
for x in range(count):
    print(num:6)
# Out:
# Enter the numbers or sentence: 6
# Enter the count: 9
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6

# %%
txt="hello"
count=int(input("Enter count:"))
for i in range(6):
    print(txt)
# Out:
# Enter count: 90
# hello
# hello
# hello
# hello
# hello
# hello

# %%
username=["user1","user2","user3"]
password=["123","456","789"]
u=input("Enter the username:")
p=input("Enter the password:")
if u=="user1" and p=="123":
    print("Login Successful!")
elif u=="user2" and p=="456":
    print("Login Successful!")
elif u=="user3" and p=="789":
    print("Login Successful!")
else:
    print("Login Failed!")
# Out:
# Enter the username: user3
# Enter the password: 123
# Login Failed!

# %%
b=input("Enter the value:")
a=5
for i in range(a,0,-1):
    print(b *i)
# Out:
# Enter the value: 8
# 88888
# 8888
# 888
# 88
# 8

# %%
b=input("Enter the value:")
a=5
for i in range(a,0,+1):
    print(b *i)
for j in range(a,0,+1):
    print(b *i,*j)
# Out:
# Enter the value: 7

# %%
a=int(input("Enter the end value:"))
for i in range(1,a+1,2):
    print(i)
# Out:
# Enter the end value: 10
# 1
# 3
# 5
# 7
# 9
